# %% [markdown]
# <a href="https://colab.research.google.com/github/NGS-Adryan/Colab/blob/gsheet/creating_and_edit_google_sheets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

#sh = gc.create('coordenadas')

# %%
ws = gc.open_by_url('https://docs.google.com/spreadsheets/d/1PmiEZfWn8NSfjtyQux49EPaGJHXTtDoy6ISJwtQ2e7A/edit#gid=0').sheet1

# %%
# cell_list = ws.range('A1:C2')
# import random
# for cell in cell_list:
  # cell.value = random.randint(1, 10)

# ws.update_cells(cell_list)
# rows = ws.get_all_values()
# print(rows)

# %%
rows = ws.get_all_values()
# for row in rows:
#  print(row)

# %%
import pandas as pd

df = pd.DataFrame.from_records(rows)
df.columns = df.iloc[0]
df = df[1:]
df.reset_index(drop=True).head(3)
# Out:
# 0   Latitude  Longitude                               Endereço
# 0  -30,00099  -51,18977                         Rua Edu Chaves
# 1  -29,99242   -51,1142  Avenida Francisco Silveira Bitencourt
# 2  -30,02377  -51,10774             Avenida Martim Félix Berta

# %%
from geopy.geocoders import Nominatim

latitude = -30.00099
longitude = -51.18977

geolocator = Nominatim(user_agent="Adryan")
location = geolocator.reverse((latitude, longitude), language='pt-BR')
# location.raw['address']
address = location.raw['address']
', nº '.join([address['road'], address['house_number']])
# Out:
# 'Rua Edu Chaves, nº 468'

# %%
import requests

endereço = []

for lat, lon in zip(df['Latitude'], df['Longitude']):
  # print(lat, '', lon)
  lat, lon  = float(lat.replace(',', '.')), float(lon.replace(',', '.'))
  url = f'https://nominatim.openstreetmap.org/reverse?format=json&lat={lat}&lon={lon}&language=pt-BR'
  response = requests.get(url)
  data = response.json()
  try:
    endereço.append(data['address']['road'])
  except:
    endereço.append(data['address'])
  #location = geolocator.reverse((lat, lon), language='pt-BR')
  #endereço.append(location.address)
  #endereço

df['Endereço'] = endereço

df.head(5)
# Out:
# 0   Latitude  Longitude                               Endereço
# 1  -30,00099  -51,18977                         Rua Edu Chaves
# 2  -29,99242   -51,1142  Avenida Francisco Silveira Bitencourt
# 3  -30,02377  -51,10774             Avenida Martim Félix Berta
# 4  -29,99418  -51,12929                   Avenida Assis Brasil
# 5  -30,02633  -51,10801             Avenida Martim Félix Berta

# %%
enderecos = df['Endereço'].tolist()

for i in range(len(enderecos)):
  ws.update(f'C{i + 2}', str(enderecos[i]))

# %%
ws.get_all_values()
# Out:
# [['Latitude', 'Longitude', 'Endereço'],
#  ['-30,00099', '-51,18977', 'Rua Edu Chaves'],
#  ['-29,99242', '-51,1142', 'Avenida Francisco Silveira Bitencourt'],
#  ['-30,02377', '-51,10774', 'Avenida Martim Félix Berta'],
#  ['-29,99418', '-51,12929', 'Avenida Assis Brasil'],
#  ['-30,02633', '-51,10801', 'Avenida Martim Félix Berta'],
#  ['-30,00238', '-51,18823', 'Corredor de Transporte Coletivo Sertório'],
#  ['-30,02791', '-51,10752', 'Avenida Martim Félix Berta'],
#  ['-29,99068', '-51,18421', 'Avenida Zaida Jarros'],
#  ['-29,99379', '-51,12089', 'Avenida Francisco Silveira Bitencourt'],
#  ['-29,98785', '-51,18125', 'Terminal de Integração Trensurb / Aeroporto'],
#  ['-29,99887', '-51,11473', 'Avenida Plínio Kroeff'],
#  ['-30,02797', '-51,10747', 'Avenida Martim Félix Berta'],
#  ['-29,98701', '-51,16867', 'Avenida das Indústrias'],
#  ['-30,00849', '-51,11787', 'Avenida Dante Ângelo Pilla'],
#  ['-29,98597', '-51,16431', 'Avenida das Indústrias'],
# ...
